# %%
import random 
import gym
import numpy as np 
from collections import deque
import tensorflow as tf 
import tflearn as tl 
from tflearn.activations import softmax
# Out:
# WARNING:tensorflow:From E:\Users\L3\.conda\envs\ML\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
episode_infos = {'run' : [], 'step' : [], 'total_reward' : [], 'avg_reward' : []}

# %%
def cartpole():
    env = gym.make('CartPole-v1')
    observation_space = env.observation_space.shape[0]
    action_space = env.action_space.n
    sess = tf.InteractiveSession()
    a3c_solver = A3CSolver(observation_space, action_space, sess)
    sess.run(tf.global_variables_initializer())
    #a3c_solver.model.load_weights('dqn_weights_%i.h5' % (prev_stop))
    run = 0
    while True:
    #for _ in range(300):
        run += 1
        state = env.reset()
        state = np.reshape(state, [1, observation_space])
        step = 0
        total_reward = 0
        while True:
            step += 1
            action = a3c_solver.act(state)
            state_next, reward, terminal, info = env.step(action)
            reward = reward if not terminal else -reward
            total_reward += reward
            state_next = np.reshape(state_next, [1, observation_space])
            a3c_solver.remember(state, action, reward, state_next, terminal)
            state = state_next
            if terminal:
                
                episode_infos['run'].append(run)
                episode_infos['step'].append(step)
                episode_infos['total_reward'].append(total_reward)
                episode_infos['avg_reward'].append(total_reward / step)
                
                print('epsilon : ' + str(a3c_solver.exploration_rate))
                print('run : ' + str(run) + ' score : ' + str(total_reward) + ' avg_score : ' + str(total_reward / step))
                break
            a3c_solver.experience_replay()
        #dqn_solver.model.save_weights('dqn_weights_%i.h5' % (run))

# %% [markdown]
# ### Loss function :
# $$L= L_\pi + \alpha L_Q + \beta L_{reg}$$
# ### Policy loss :
# $$A = (R - Q_{a_i\sim \pi}(a_i,s_i; \theta'_q))$$
# $$\frac{\partial\,J(\pi)}{\partial\, \theta'} = \frac{1}{n}\sum_{i=1}^{n}\frac{\partial\,log\,\pi (a_i|s_i;\theta')}{\partial\,\theta'}\; A$$
# $$\therefore J(\pi) = \frac{1}{n}\sum_{i=1}^{n}log\,\pi (a_i|s_i;\theta')\; A\;\;\;\;\;\;[\because A\;is\;considered\;constant]$$
# ∵ We want to maximize 𝐽(𝜋) $$L_\pi = -J(\pi)$$
# ### Value loss :
# $$J(Q) = \sum_{i=1}^{n}(R - Q_{a_i\sim \pi}(a_i,s_i; \theta'_q))$$
# $$L_Q = J(Q)$$
# ### Policy entropy :
# $$H(\overrightarrow{\pi(s)})=-\sum_{i=1}^{n}\sum_{k=1}^{m} \pi(s_i)_k\cdot log\, \pi(s_i)_k$$
# $$L_{reg}=H(\overrightarrow{\pi(s)})$$

# %%
y = 0.95
l_rate = 0.0001

exp_memory_size = 10000
batch_size = 32

exploration_max = 1.0
exploration_min = 0.01
exploration_decay = 0.9995

alpha = 0.5
beta = 0.1

# %%
class A3CSolver():
    def __init__(self, observation_space, action_space, sess):
        self.sess = sess
        self.exploration_rate = exploration_max
        self.action_space = action_space
        self.memory = deque(maxlen = exp_memory_size)
        
        self.state = tl.input_data(shape = [None, observation_space], name = 'S_i')
        self.action = tl.input_data(shape = [None, action_space], name = 'A_i')
        self.R = tl.input_data(shape = [None, 1], name = 'R_i')
        
        #Actor 𝜋(a_i|s_i;𝜃′)
        self.actor = self.build_actor(self.state, action_space)
        #Critic Q_a_i∼𝜋(a_i,s_i;𝜃′_q)
        self.critic = self.build_critic(self.state, self.action)
        
        #Loss L
        self.loss = self.compute_loss()
        #Optimize ops 
        self.opt = tf.train.AdamOptimizer(learning_rate = l_rate).minimize(self.loss)
        
    def build_actor(self, state_input, action_space):
        with tf.variable_scope('actor', reuse = tf.AUTO_REUSE):
            #State input s_i
            #a_h1 = tl.fully_connected(state_input, 24)        
            #a_h2 = tl.fully_connected(a_h1, 48)        
            #a_logit = tl.fully_connected(a_h2, action_space)
            a_logit = tl.fully_connected(state_input, action_space)
            return softmax(a_logit)
    
    def build_critic(self, state_input, action_input):
        with tf.variable_scope('critic', reuse = tf.AUTO_REUSE):
            #Action input a_i
            as_h1 = tl.fully_connected(action_input, 24)
            as_h2 = tl.fully_connected(as_h1, 48)
            #State input s_i
            ss_h1 = tl.fully_connected(state_input, 24)
            ss_h2 = tl.fully_connected(ss_h1, 48)
            #Combine state action input 
            q_h1 = tl.layers.merge_ops.merge([as_h2, ss_h2], mode = 'elemwise_sum')
            return tl.fully_connected(q_h1, 1)
    
    def remember(self, state, action, reward, state_next, done):
        self.memory.append([state, action, reward, state_next, done])
        
    def act(self, state, infer = False):
        #act
        if not infer and np.random.rand() < self.exploration_rate:
            return random.randrange(self.action_space)
        action = self.sess.run(self.actor, feed_dict = {self.state : state})
        return np.argmax(action[0])
    
    def experience_replay(self):
        if len(self.memory) < batch_size:
            return
        batch = random.sample(self.memory, batch_size)
        for state, action, reward, state_next, done in batch:
            R = np.array(reward).reshape([1, 1])
            action = np.identity(2)[action].reshape([1, self.action_space])
            if not done:
                action_next = self.sess.run(self.actor, feed_dict = {self.state : state_next})
                #R = reward + y * self.sess.run(self.critic, feed_dict = {self.state : state_next, self.action : action_next})
            else:
                R = np.array(-10).reshape([1, 1]) 
            #Optimize
            loss, _, a, b, c= self.sess.run([self.loss, self.opt, self.L_pi, self.L_v, self.actor], feed_dict = {self.state : state, 
                                                                        self.action : action, 
                                                                        self.R : R})
            #print(loss, a, b, c)
            self.exploration_rate *= exploration_decay
            self.exploration_rate = max(exploration_min, self.exploration_rate)

    def compute_loss(self):
        #Advantage
        A = self.R #- self.critic
        #Policy loss 
        self.L_pi = - tf.reduce_mean(tf.reduce_sum(tf.log(self.actor + 1e-13) * tf.stop_gradient(A), axis = -1))
        #Value loss
        self.L_v = tf.reduce_mean(tf.math.square(A))
        #Policy entropy 
        self.L_reg = - tf.reduce_mean(tf.reduce_sum(tf.multiply(self.actor, tf.log(self.actor + 1e-13)), axis = -1))
        #Total loss 
        return self.L_pi #+ alpha * self.L_v #+ beta * self.L_reg

# %%
cartpole()
# Out:
# WARNING:tensorflow:From E:\Users\L3\.conda\envs\ML\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# epsilon : 1.0
# run : 1 score : 11.0 avg_score : 0.8461538461538461
# epsilon : 0.7260909281046787
# run : 2 score : 37.0 avg_score : 0.9487179487179487
# epsilon : 0.5188377554109553
# run : 3 score : 20.0 avg_score : 0.9090909090909091
# epsilon : 0.09361242136549094
# run : 4 score : 106.0 avg_score : 0.9814814814814815
# epsilon : 0.03700048439120764
# run : 5 score : 57.0 avg_score : 0.9661016949152542
# epsilon : 0.01584286012477932
# run : 6 score : 52.0 avg_score : 0.9629629629629629
# epsilon : 0.01
# run : 7 score : 311.0 avg_score : 0.9936102236421726
# epsilon : 0.01
# run : 8 score : 88.0 avg_score : 0.9777777777777777
# epsilon : 0.01
# run : 9 score : 129.0 avg_score : 0.9847328244274809
# epsilon : 0.01
# run : 10 score : 60.0 avg_score : 0.967741935483871
# epsilon : 0.01
# run : 11 score : 73.0 avg_score : 0.9733333333333334
# epsilon : 0.01
# run : 12 score : 145.0 avg_score : 0.9863945578231292
# epsilon : 0.01
# run : 13 score : 62.0 avg_score : 0.96875
# epsilon : 0.01
# run : 14 score : 103.0 avg_score : 0.9809523809523809
# epsilon : 0.01
# run : 15 score : 288.0 avg_score : 0.993103448275862
# epsilon : 0.01
# run : 16 score : 188.0 avg_score : 0.9894736842105263
# epsilon : 0.01
# run : 17 score : 106.0 avg_score : 0.9814814814814815
# epsilon : 0.01
# run : 18 score : 82.0 avg_score : 0.9761904761904762
# epsilon : 0.01
# run : 19 score : 82.0 avg_score : 0.9761904761904762
# epsilon : 0.01
# run : 20 score : 97.0 avg_score : 0.9797979797979798
# epsilon : 0.01
# run : 21 score : 201.0 avg_score : 0.9901477832512315
# epsilon : 0.01
# run : 22 score : 105.0 avg_score : 0.9813084112149533
# epsilon : 0.01
# run : 23 score : 145.0 avg_score : 0.9863945578231292
# epsilon : 0.01
# run : 24 score : 85.0 avg_score : 0.9770114942528736
# epsilon : 0.01
# run : 25 score : 130.0 avg_score : 0.9848484848484849
# epsilon : 0.01
# run : 26 score : 94.0 avg_score : 0.9791666666666666
# epsilon : 0.01
# run : 27 score : 126.0 avg_score : 0.984375
# epsilon : 0.01
# run : 28 score : 116.0 avg_score : 0.9830508474576272
# epsilon : 0.01
# run : 29 score : 96.0 avg_score : 0.9795918367346939
# epsilon : 0.01
# run : 30 score : 86.0 avg_score : 0.9772727272727273
# epsilon : 0.01
# run : 31 score : 82.0 avg_score : 0.9761904761904762
# epsilon : 0.01
# run : 32 score : 129.0 avg_score : 0.9847328244274809
# epsilon : 0.01
# run : 33 score : 109.0 avg_score : 0.9819819819819819
# epsilon : 0.01
# run : 34 score : 130.0 avg_score : 0.9848484848484849
# epsilon : 0.01
# run : 35 score : 98.0 avg_score : 0.98
# epsilon : 0.01
# run : 36 score : 113.0 avg_score : 0.9826086956521739
# epsilon : 0.01
# run : 37 score : 112.0 avg_score : 0.9824561403508771
# epsilon : 0.01
# run : 38 score : 119.0 avg_score : 0.9834710743801653
# epsilon : 0.01
# run : 39 score : 111.0 avg_score : 0.9823008849557522
# epsilon : 0.01
# run : 40 score : 121.0 avg_score : 0.983739837398374
# epsilon : 0.01
# run : 41 score : 99.0 avg_score : 0.9801980198019802
# epsilon : 0.01
# run : 42 score : 218.0 avg_score : 0.990909090909091
# epsilon : 0.01
# run : 43 score : 120.0 avg_score : 0.9836065573770492
# epsilon : 0.01
# run : 44 score : 141.0 avg_score : 0.986013986013986
# epsilon : 0.01
# run : 45 score : 132.0 avg_score : 0.9850746268656716
# epsilon : 0.01
# run : 46 score : 147.0 avg_score : 0.9865771812080537
# epsilon : 0.01
# run : 47 score : 111.0 avg_score : 0.9823008849557522
# epsilon : 0.01
# run : 48 score : 169.0 avg_score : 0.9883040935672515
# epsilon : 0.01
# run : 49 score : 142.0 avg_score : 0.9861111111111112
# epsilon : 0.01
# run : 50 score : 174.0 avg_score : 0.9886363636363636
# epsilon : 0.01
# run : 51 score : 128.0 avg_score : 0.9846153846153847
# epsilon : 0.01
# run : 52 score : 167.0 avg_score : 0.9881656804733728
# epsilon : 0.01
# run : 53 score : 111.0 avg_score : 0.9823008849557522
# epsilon : 0.01
# run : 54 score : 134.0 avg_score : 0.9852941176470589
# epsilon : 0.01
# run : 55 score : 173.0 avg_score : 0.9885714285714285
# epsilon : 0.01
# run : 56 score : 108.0 avg_score : 0.9818181818181818
# epsilon : 0.01
# run : 57 score : 115.0 avg_score : 0.9829059829059829
# epsilon : 0.01
# run : 58 score : 138.0 avg_score : 0.9857142857142858
# epsilon : 0.01
# run : 59 score : 102.0 avg_score : 0.9807692307692307
# epsilon : 0.01
# run : 60 score : 113.0 avg_score : 0.9826086956521739
# epsilon : 0.01
# run : 61 score : 99.0 avg_score : 0.9801980198019802
# epsilon : 0.01
# run : 62 score : 126.0 avg_score : 0.984375
# epsilon : 0.01
# run : 63 score : 98.0 avg_score : 0.98
# epsilon : 0.01
# run : 64 score : 156.0 avg_score : 0.9873417721518988
# epsilon : 0.01
# run : 65 score : 188.0 avg_score : 0.9894736842105263
# epsilon : 0.01
# run : 66 score : 125.0 avg_score : 0.984251968503937
# epsilon : 0.01
# run : 67 score : 110.0 avg_score : 0.9821428571428571
# epsilon : 0.01
# run : 68 score : 101.0 avg_score : 0.9805825242718447
# epsilon : 0.01
# run : 69 score : 140.0 avg_score : 0.9859154929577465
# epsilon : 0.01
# run : 70 score : 151.0 avg_score : 0.9869281045751634
# epsilon : 0.01
# run : 71 score : 127.0 avg_score : 0.9844961240310077
# epsilon : 0.01
# run : 72 score : 163.0 avg_score : 0.9878787878787879
# epsilon : 0.01
# run : 73 score : 63.0 avg_score : 0.9692307692307692
# epsilon : 0.01
# run : 74 score : 153.0 avg_score : 0.9870967741935484
# epsilon : 0.01
# run : 75 score : 101.0 avg_score : 0.9805825242718447
# epsilon : 0.01
# run : 76 score : 82.0 avg_score : 0.9761904761904762
# epsilon : 0.01
# run : 77 score : 76.0 avg_score : 0.9743589743589743
# epsilon : 0.01
# run : 78 score : 90.0 avg_score : 0.9782608695652174
# epsilon : 0.01
# run : 79 score : 171.0 avg_score : 0.9884393063583815
# epsilon : 0.01
# run : 80 score : 162.0 avg_score : 0.9878048780487805
# epsilon : 0.01
# run : 81 score : 157.0 avg_score : 0.9874213836477987
# epsilon : 0.01
# run : 82 score : 139.0 avg_score : 0.9858156028368794
# epsilon : 0.01
# run : 83 score : 128.0 avg_score : 0.9846153846153847
# epsilon : 0.01
# run : 84 score : 121.0 avg_score : 0.983739837398374
# epsilon : 0.01
# run : 85 score : 89.0 avg_score : 0.978021978021978
# epsilon : 0.01
# run : 86 score : 156.0 avg_score : 0.9873417721518988
# epsilon : 0.01
# run : 87 score : 185.0 avg_score : 0.9893048128342246
# epsilon : 0.01
# run : 88 score : 128.0 avg_score : 0.9846153846153847
# epsilon : 0.01
# run : 89 score : 56.0 avg_score : 0.9655172413793104
# epsilon : 0.01
# run : 90 score : 90.0 avg_score : 0.9782608695652174
# epsilon : 0.01
# run : 91 score : 53.0 avg_score : 0.9636363636363636
# epsilon : 0.01
# run : 92 score : 98.0 avg_score : 0.98
# epsilon : 0.01
# run : 93 score : 146.0 avg_score : 0.9864864864864865
# epsilon : 0.01
# run : 94 score : 54.0 avg_score : 0.9642857142857143
# epsilon : 0.01
# run : 95 score : 131.0 avg_score : 0.9849624060150376
# epsilon : 0.01
# run : 96 score : 131.0 avg_score : 0.9849624060150376
# epsilon : 0.01
# run : 97 score : 118.0 avg_score : 0.9833333333333333
# epsilon : 0.01
# run : 98 score : 61.0 avg_score : 0.9682539682539683
# epsilon : 0.01
# run : 99 score : 72.0 avg_score : 0.972972972972973
# epsilon : 0.01
# run : 100 score : 70.0 avg_score : 0.9722222222222222
# epsilon : 0.01
# run : 101 score : 91.0 avg_score : 0.978494623655914
# epsilon : 0.01
# run : 102 score : 47.0 avg_score : 0.9591836734693877
# epsilon : 0.01
# run : 103 score : 296.0 avg_score : 0.9932885906040269
# epsilon : 0.01
# run : 104 score : 129.0 avg_score : 0.9847328244274809
# epsilon : 0.01
# run : 105 score : 37.0 avg_score : 0.9487179487179487
# epsilon : 0.01
# run : 106 score : 184.0 avg_score : 0.989247311827957
# epsilon : 0.01
# run : 107 score : 110.0 avg_score : 0.9821428571428571
# epsilon : 0.01
# run : 108 score : 98.0 avg_score : 0.98
# epsilon : 0.01
# run : 109 score : 151.0 avg_score : 0.9869281045751634
# epsilon : 0.01
# run : 110 score : 129.0 avg_score : 0.9847328244274809
# epsilon : 0.01
# run : 111 score : 125.0 avg_score : 0.984251968503937
# epsilon : 0.01
# run : 112 score : 101.0 avg_score : 0.9805825242718447
# epsilon : 0.01
# run : 113 score : 125.0 avg_score : 0.984251968503937
# epsilon : 0.01
# run : 114 score : 181.0 avg_score : 0.9890710382513661
# epsilon : 0.01
# run : 115 score : 100.0 avg_score : 0.9803921568627451
# epsilon : 0.01
# run : 116 score : 24.0 avg_score : 0.9230769230769231
# epsilon : 0.01
# run : 117 score : 51.0 avg_score : 0.9622641509433962
# epsilon : 0.01
# run : 118 score : 23.0 avg_score : 0.92
# epsilon : 0.01
# run : 119 score : 45.0 avg_score : 0.9574468085106383
# epsilon : 0.01
# run : 120 score : 49.0 avg_score : 0.9607843137254902
# epsilon : 0.01
# run : 121 score : 20.0 avg_score : 0.9090909090909091
# epsilon : 0.01
# run : 122 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 123 score : 9.0 avg_score : 0.8181818181818182
# epsilon : 0.01
# run : 124 score : 41.0 avg_score : 0.9534883720930233
# epsilon : 0.01
# run : 125 score : 24.0 avg_score : 0.9230769230769231
# epsilon : 0.01
# run : 126 score : 19.0 avg_score : 0.9047619047619048
# epsilon : 0.01
# run : 127 score : 22.0 avg_score : 0.9166666666666666
# epsilon : 0.01
# run : 128 score : 40.0 avg_score : 0.9523809523809523
# epsilon : 0.01
# run : 129 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 130 score : 21.0 avg_score : 0.9130434782608695
# epsilon : 0.01
# run : 131 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 132 score : 14.0 avg_score : 0.875
# epsilon : 0.01
# run : 133 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 134 score : 25.0 avg_score : 0.9259259259259259
# epsilon : 0.01
# run : 135 score : 28.0 avg_score : 0.9333333333333333
# epsilon : 0.01
# run : 136 score : 24.0 avg_score : 0.9230769230769231
# epsilon : 0.01
# run : 137 score : 110.0 avg_score : 0.9821428571428571
# epsilon : 0.01
# run : 138 score : 65.0 avg_score : 0.9701492537313433
# epsilon : 0.01
# run : 139 score : 117.0 avg_score : 0.9831932773109243
# epsilon : 0.01
# run : 140 score : 78.0 avg_score : 0.975
# epsilon : 0.01
# run : 141 score : 82.0 avg_score : 0.9761904761904762
# epsilon : 0.01
# run : 142 score : 118.0 avg_score : 0.9833333333333333
# epsilon : 0.01
# run : 143 score : 28.0 avg_score : 0.9333333333333333
# epsilon : 0.01
# run : 144 score : 98.0 avg_score : 0.98
# epsilon : 0.01
# run : 145 score : 122.0 avg_score : 0.9838709677419355
# epsilon : 0.01
# run : 146 score : 156.0 avg_score : 0.9873417721518988
# epsilon : 0.01
# run : 147 score : 179.0 avg_score : 0.988950276243094
# epsilon : 0.01
# run : 148 score : 183.0 avg_score : 0.9891891891891892
# epsilon : 0.01
# run : 149 score : 167.0 avg_score : 0.9881656804733728
# epsilon : 0.01
# run : 150 score : 148.0 avg_score : 0.9866666666666667
# epsilon : 0.01
# run : 151 score : 157.0 avg_score : 0.9874213836477987
# epsilon : 0.01
# run : 152 score : 105.0 avg_score : 0.9813084112149533
# epsilon : 0.01
# run : 153 score : 179.0 avg_score : 0.988950276243094
# epsilon : 0.01
# run : 154 score : 120.0 avg_score : 0.9836065573770492
# epsilon : 0.01
# run : 155 score : 269.0 avg_score : 0.992619926199262
# epsilon : 0.01
# run : 156 score : 158.0 avg_score : 0.9875
# epsilon : 0.01
# run : 157 score : 214.0 avg_score : 0.9907407407407407
# epsilon : 0.01
# run : 158 score : 194.0 avg_score : 0.9897959183673469
# epsilon : 0.01
# run : 159 score : 143.0 avg_score : 0.9862068965517241
# epsilon : 0.01
# run : 160 score : 318.0 avg_score : 0.99375
# epsilon : 0.01
# run : 161 score : 228.0 avg_score : 0.991304347826087
# epsilon : 0.01
# run : 162 score : 169.0 avg_score : 0.9883040935672515
# epsilon : 0.01
# run : 163 score : 184.0 avg_score : 0.989247311827957
# epsilon : 0.01
# run : 164 score : 245.0 avg_score : 0.9919028340080972
# epsilon : 0.01
# run : 165 score : 155.0 avg_score : 0.9872611464968153
# epsilon : 0.01
# run : 166 score : 220.0 avg_score : 0.990990990990991
# epsilon : 0.01
# run : 167 score : 214.0 avg_score : 0.9907407407407407
# epsilon : 0.01
# run : 168 score : 156.0 avg_score : 0.9873417721518988
# epsilon : 0.01
# run : 169 score : 160.0 avg_score : 0.9876543209876543
# epsilon : 0.01
# run : 170 score : 208.0 avg_score : 0.9904761904761905
# epsilon : 0.01
# run : 171 score : 163.0 avg_score : 0.9878787878787879
# epsilon : 0.01
# run : 172 score : 213.0 avg_score : 0.9906976744186047
# epsilon : 0.01
# run : 173 score : 160.0 avg_score : 0.9876543209876543
# epsilon : 0.01
# run : 174 score : 181.0 avg_score : 0.9890710382513661
# epsilon : 0.01
# run : 175 score : 138.0 avg_score : 0.9857142857142858
# epsilon : 0.01
# run : 176 score : 167.0 avg_score : 0.9881656804733728
# epsilon : 0.01
# run : 177 score : 204.0 avg_score : 0.9902912621359223
# epsilon : 0.01
# run : 178 score : 131.0 avg_score : 0.9849624060150376
# epsilon : 0.01
# run : 179 score : 275.0 avg_score : 0.9927797833935018
# epsilon : 0.01
# run : 180 score : 263.0 avg_score : 0.9924528301886792
# epsilon : 0.01
# run : 181 score : 204.0 avg_score : 0.9902912621359223
# epsilon : 0.01
# run : 182 score : 157.0 avg_score : 0.9874213836477987
# epsilon : 0.01
# run : 183 score : 204.0 avg_score : 0.9902912621359223
# epsilon : 0.01
# run : 184 score : 210.0 avg_score : 0.9905660377358491
# epsilon : 0.01
# run : 185 score : 186.0 avg_score : 0.9893617021276596
# epsilon : 0.01
# run : 186 score : 178.0 avg_score : 0.9888888888888889
# epsilon : 0.01
# run : 187 score : 180.0 avg_score : 0.989010989010989
# epsilon : 0.01
# run : 188 score : 365.0 avg_score : 0.9945504087193461
# epsilon : 0.01
# run : 189 score : 174.0 avg_score : 0.9886363636363636
# epsilon : 0.01
# run : 190 score : 149.0 avg_score : 0.9867549668874173
# epsilon : 0.01
# run : 191 score : 182.0 avg_score : 0.9891304347826086
# epsilon : 0.01
# run : 192 score : 162.0 avg_score : 0.9878048780487805
# epsilon : 0.01
# run : 193 score : 266.0 avg_score : 0.9925373134328358
# epsilon : 0.01
# run : 194 score : 169.0 avg_score : 0.9883040935672515
# epsilon : 0.01
# run : 195 score : 155.0 avg_score : 0.9872611464968153
# epsilon : 0.01
# run : 196 score : 192.0 avg_score : 0.9896907216494846
# epsilon : 0.01
# run : 197 score : 210.0 avg_score : 0.9905660377358491
# epsilon : 0.01
# run : 198 score : 151.0 avg_score : 0.9869281045751634
# epsilon : 0.01
# run : 199 score : 145.0 avg_score : 0.9863945578231292
# epsilon : 0.01
# run : 200 score : 96.0 avg_score : 0.9795918367346939
# epsilon : 0.01
# run : 201 score : 111.0 avg_score : 0.9823008849557522
# epsilon : 0.01
# run : 202 score : 123.0 avg_score : 0.984
# epsilon : 0.01
# run : 203 score : 125.0 avg_score : 0.984251968503937
# epsilon : 0.01
# run : 204 score : 107.0 avg_score : 0.981651376146789
# epsilon : 0.01
# run : 205 score : 285.0 avg_score : 0.9930313588850174
# epsilon : 0.01
# run : 206 score : 98.0 avg_score : 0.98
# epsilon : 0.01
# run : 207 score : 217.0 avg_score : 0.9908675799086758
# epsilon : 0.01
# run : 208 score : 103.0 avg_score : 0.9809523809523809
# epsilon : 0.01
# run : 209 score : 63.0 avg_score : 0.9692307692307692
# epsilon : 0.01
# run : 210 score : 28.0 avg_score : 0.9333333333333333
# epsilon : 0.01
# run : 211 score : 33.0 avg_score : 0.9428571428571428
# epsilon : 0.01
# run : 212 score : 22.0 avg_score : 0.9166666666666666
# epsilon : 0.01
# run : 213 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 214 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 215 score : 9.0 avg_score : 0.8181818181818182
# epsilon : 0.01
# run : 216 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 217 score : 9.0 avg_score : 0.8181818181818182
# epsilon : 0.01
# run : 218 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 219 score : 21.0 avg_score : 0.9130434782608695
# epsilon : 0.01
# run : 220 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 221 score : 9.0 avg_score : 0.8181818181818182
# epsilon : 0.01
# run : 222 score : 13.0 avg_score : 0.8666666666666667
# epsilon : 0.01
# run : 223 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 224 score : 12.0 avg_score : 0.8571428571428571
# epsilon : 0.01
# run : 225 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 226 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 227 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 228 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 229 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 230 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 231 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 232 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 233 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 234 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 235 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 236 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 237 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 238 score : 10.0 avg_score : 0.8333333333333334
# epsilon : 0.01
# run : 239 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 240 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 241 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 242 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 243 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 244 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 245 score : 11.0 avg_score : 0.8461538461538461
# epsilon : 0.01
# run : 246 score : 10.0 avg_score : 0.8333333333333334
# epsilon : 0.01
# run : 247 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 248 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 249 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 250 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 251 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 252 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 253 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 254 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 255 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 256 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 257 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 258 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 259 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 260 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 261 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 262 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 263 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 264 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 265 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 266 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 267 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 268 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 269 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 270 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 271 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 272 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 273 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 274 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 275 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 276 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 277 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 278 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 279 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 280 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 281 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 282 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 283 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 284 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 285 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 286 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 287 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 288 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 289 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 290 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 291 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 292 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 293 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 294 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 295 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 296 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 297 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 298 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 299 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 300 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 301 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 302 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 303 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 304 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 305 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 306 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 307 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 308 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 309 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 310 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 311 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 312 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 313 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 314 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 315 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 316 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 317 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 318 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 319 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 320 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 321 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 322 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 323 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 324 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 325 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 326 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 327 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 328 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 329 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 330 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 331 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 332 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 333 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 334 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 335 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 336 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 337 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 338 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 339 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 340 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 341 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 342 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 343 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 344 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 345 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 346 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 347 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 348 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 349 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 350 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 351 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 352 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 353 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 354 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 355 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 356 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 357 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 358 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 359 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 360 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 361 score : 9.0 avg_score : 0.8181818181818182
# epsilon : 0.01
# run : 362 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 363 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 364 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 365 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 366 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 367 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 368 score : 10.0 avg_score : 0.8333333333333334
# epsilon : 0.01
# run : 369 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 370 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 371 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 372 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 373 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 374 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 375 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 376 score : 10.0 avg_score : 0.8333333333333334
# epsilon : 0.01
# run : 377 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 378 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 379 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 380 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 381 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 382 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 383 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 384 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 385 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 386 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 387 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 388 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 389 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 390 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 391 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 392 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 393 score : 9.0 avg_score : 0.8181818181818182
# epsilon : 0.01
# run : 394 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 395 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 396 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 397 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 398 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 399 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 400 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 401 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 402 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 403 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 404 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 405 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 406 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 407 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 408 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 409 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 410 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 411 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 412 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 413 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 414 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 415 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 416 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 417 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 418 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 419 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 420 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 421 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 422 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 423 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 424 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 425 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 426 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 427 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 428 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 429 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 430 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 431 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 432 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 433 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 434 score : 10.0 avg_score : 0.8333333333333334
# epsilon : 0.01
# run : 435 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 436 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 437 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 438 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 439 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 440 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 441 score : 9.0 avg_score : 0.8181818181818182
# epsilon : 0.01
# run : 442 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 443 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 444 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 445 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 446 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 447 score : 9.0 avg_score : 0.8181818181818182
# epsilon : 0.01
# run : 448 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 449 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 450 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 451 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 452 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 453 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 454 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 455 score : 9.0 avg_score : 0.8181818181818182
# epsilon : 0.01
# run : 456 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 457 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 458 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 459 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 460 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 461 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 462 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 463 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 464 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 465 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 466 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 467 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 468 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 469 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 470 score : 9.0 avg_score : 0.8181818181818182
# epsilon : 0.01
# run : 471 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 472 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 473 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 474 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 475 score : 9.0 avg_score : 0.8181818181818182
# epsilon : 0.01
# run : 476 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 477 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 478 score : 9.0 avg_score : 0.8181818181818182
# epsilon : 0.01
# run : 479 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 480 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 481 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 482 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 483 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 484 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 485 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 486 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 487 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 488 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 489 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 490 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 491 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 492 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 493 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 494 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 495 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 496 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 497 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 498 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 499 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 500 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 501 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 502 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 503 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 504 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 505 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 506 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 507 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 508 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 509 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 510 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 511 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 512 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 513 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 514 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 515 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 516 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 517 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 518 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 519 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 520 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 521 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 522 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 523 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 524 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 525 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 526 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 527 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 528 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 529 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 530 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 531 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 532 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 533 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 534 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 535 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 536 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 537 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 538 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 539 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 540 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 541 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 542 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 543 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 544 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 545 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 546 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 547 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 548 score : 9.0 avg_score : 0.8181818181818182
# epsilon : 0.01
# run : 549 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 550 score : 9.0 avg_score : 0.8181818181818182
# epsilon : 0.01
# run : 551 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 552 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 553 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 554 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 555 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 556 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 557 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 558 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 559 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 560 score : 9.0 avg_score : 0.8181818181818182
# epsilon : 0.01
# run : 561 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 562 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 563 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 564 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 565 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 566 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 567 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 568 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 569 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 570 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 571 score : 9.0 avg_score : 0.8181818181818182
# epsilon : 0.01
# run : 572 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 573 score : 9.0 avg_score : 0.8181818181818182
# epsilon : 0.01
# run : 574 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 575 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 576 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 577 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 578 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 579 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 580 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 581 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 582 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 583 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 584 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 585 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 586 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 587 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 588 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 589 score : 9.0 avg_score : 0.8181818181818182
# epsilon : 0.01
# run : 590 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 591 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 592 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 593 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 594 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 595 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 596 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 597 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 598 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 599 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 600 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 601 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 602 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 603 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 604 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 605 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 606 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 607 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 608 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 609 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 610 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 611 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 612 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 613 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 614 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 615 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 616 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 617 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 618 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 619 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 620 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 621 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 622 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 623 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 624 score : 9.0 avg_score : 0.8181818181818182
# epsilon : 0.01
# run : 625 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 626 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 627 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 628 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 629 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 630 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 631 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 632 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 633 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 634 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 635 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 636 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 637 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 638 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 639 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 640 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 641 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 642 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 643 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 644 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 645 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 646 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 647 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 648 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 649 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 650 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 651 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 652 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 653 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 654 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 655 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 656 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 657 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 658 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 659 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 660 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 661 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 662 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 663 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 664 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 665 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 666 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 667 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 668 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 669 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 670 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 671 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 672 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 673 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 674 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 675 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 676 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 677 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 678 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 679 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 680 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 681 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 682 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 683 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 684 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 685 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 686 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 687 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 688 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 689 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 690 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 691 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 692 score : 9.0 avg_score : 0.8181818181818182
# epsilon : 0.01
# run : 693 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 694 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 695 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 696 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 697 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 698 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 699 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 700 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 701 score : 9.0 avg_score : 0.8181818181818182
# epsilon : 0.01
# run : 702 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 703 score : 9.0 avg_score : 0.8181818181818182
# epsilon : 0.01
# run : 704 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 705 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 706 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 707 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 708 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 709 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 710 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 711 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 712 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 713 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 714 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 715 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 716 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 717 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 718 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 719 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 720 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 721 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 722 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 723 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 724 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 725 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 726 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 727 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 728 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 729 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 730 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 731 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 732 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 733 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 734 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 735 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 736 score : 9.0 avg_score : 0.8181818181818182
# epsilon : 0.01
# run : 737 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 738 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 739 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 740 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 741 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 742 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 743 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 744 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 745 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 746 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 747 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 748 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 749 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 750 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 751 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 752 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 753 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 754 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 755 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 756 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 757 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 758 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 759 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 760 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 761 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# ...
# run : 10873 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 10874 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10875 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10876 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10877 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10878 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10879 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10880 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10881 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 10882 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10883 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10884 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 10885 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 10886 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10887 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 10888 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10889 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 10890 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10891 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 10892 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 10893 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 10894 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10895 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10896 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 10897 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 10898 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10899 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 10900 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10901 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10902 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 10903 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10904 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10905 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 10906 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10907 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10908 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10909 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 10910 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 10911 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10912 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 10913 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10914 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10915 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 10916 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10917 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 10918 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 10919 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10920 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10921 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10922 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10923 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 10924 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10925 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 10926 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 10927 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10928 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10929 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10930 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10931 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10932 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10933 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 10934 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10935 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10936 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 10937 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10938 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10939 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 10940 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 10941 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10942 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 10943 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 10944 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 10945 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 10946 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10947 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 10948 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 10949 score : 9.0 avg_score : 0.8181818181818182
# epsilon : 0.01
# run : 10950 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 10951 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 10952 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10953 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10954 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10955 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 10956 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10957 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 10958 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10959 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10960 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10961 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10962 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10963 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 10964 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10965 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10966 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10967 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10968 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10969 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10970 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 10971 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10972 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10973 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10974 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 10975 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 10976 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 10977 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10978 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10979 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10980 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 10981 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 10982 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10983 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10984 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10985 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 10986 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10987 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 10988 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 10989 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10990 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10991 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10992 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10993 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10994 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10995 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10996 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 10997 score : 9.0 avg_score : 0.8181818181818182
# epsilon : 0.01
# run : 10998 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 10999 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 11000 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 11001 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 11002 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 11003 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 11004 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 11005 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 11006 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 11007 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 11008 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 11009 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 11010 score : 9.0 avg_score : 0.8181818181818182
# epsilon : 0.01
# run : 11011 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 11012 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 11013 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 11014 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 11015 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 11016 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 11017 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 11018 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 11019 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 11020 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 11021 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 11022 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 11023 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 11024 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 11025 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 11026 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 11027 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 11028 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 11029 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 11030 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 11031 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 11032 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 11033 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 11034 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 11035 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 11036 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 11037 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 11038 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 11039 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 11040 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 11041 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 11042 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 11043 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 11044 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 11045 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 11046 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 11047 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 11048 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 11049 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 11050 score : 9.0 avg_score : 0.8181818181818182
# epsilon : 0.01
# run : 11051 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 11052 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 11053 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 11054 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 11055 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 11056 score : 6.0 avg_score : 0.75
# epsilon : 0.01
# run : 11057 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 11058 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 11059 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 11060 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 11061 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 11062 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 11063 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 11064 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 11065 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 11066 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 11067 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 11068 score : 7.0 avg_score : 0.7777777777777778
# epsilon : 0.01
# run : 11069 score : 8.0 avg_score : 0.8
# epsilon : 0.01
# run : 11070 score : 7.0 avg_score : 0.7777777777777778
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-3-e18952c97fc4> in cartpole()
#      34                 print('run : ' + str(run) + ' score : ' + str(total_reward) + ' avg_score : ' + str(total_reward / step))
#      35                 break
# ---> 36             a3c_solver.experience_replay()
#      37         #dqn_solver.model.save_weights('dqn_weights_%i.h5' % (run))
#
# <ipython-input-5-e0dd9c4ab935> in experience_replay(self)
#      59             action = np.identity(2)[action].reshape([1, self.action_space])
#      60             if not done:
# ---> 61                 action_next = self.sess.run(self.actor, feed_dict = {self.state : state_next})
#      62                 #R = reward + y * self.sess.run(self.critic, feed_dict = {self.state : state_next, self.action : action_next})
#      63             else:
#
# ~\.conda\envs\ML\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\.conda\envs\ML\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# ~\.conda\envs\ML\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~\.conda\envs\ML\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1332   def _do_call(self, fn, *args):
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#    1336       message = compat.as_text(e.message)
#
# ~\.conda\envs\ML\lib\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1317       self._extend_graph()
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#    1321     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~\.conda\envs\ML\lib\site-packages\tensorflow\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1405     return tf_session.TF_SessionRun_wrapper(
#    1406         self._session, options, feed_dict, fetch_list, target_list,
# -> 1407         run_metadata)
#    1408
#    1409   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
episode_infos['run'][-1]
# Out:
# 11070

# %%
from matplotlib import pyplot as plt

# %%
plt.xlabel('episode')
plt.ylabel('reward')
plt.plot(episode_infos['run'][:500], episode_infos['total_reward'][:500])
